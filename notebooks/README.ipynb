# %%
from pathlib import Path

# Make relative README paths and app.py commands work whether the notebook
# is opened from the repo root or from notebooks/.
if not Path("app.py").exists() and Path("../app.py").exists():
    # %cd ..
# Out:
# /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine

# %% [markdown]
# # aid-ressource-allocation-engine
#
# *A decision-support engine for humanitarian aid allocation in Somalia. The system combines regional food and water forecasts, national CMB and fuel proxies, and Copernicus weather indicators to allocate scarce aid capacity across food supplies, water supplies, fuel, and water infrastructure equipment, with an overall deterministic reasoning summary.*
#
# ## Somalia
#
# Somalia has suffered from prolonged conflict, resulting in weak infrastructure on top of that recurrent droughts, and heat waves plaege the region. As a result the somali population regularly suffers from water and food shortages often resulting in wide spread famines.
#
# ![](README/img/somalia_famine.png)
#
#
# Thats where Humanitarian organisations step in, but - funding  is limited. Moreover is it often wasted by poor ressource management. Humanitarian organisations have trouble predicting where and in which quantity certain aids will be needed.
#
#
# ## Upside
#
# Somalia has a useful advantage: time-series data for food, water, and fuel prices is surprisingly available.
# Because food and water are sourced regionally, regional weather data can be used as an early indicator for drought pressure and future market stress.
#
#
# ## Idea
#
# Combine regional and national market time series for food, water, and fuel prices with satellite-based weather data.
#
# The resulting time series are sent to Sybilion for forecasting. A deterministic, rule-based agentic layer then turns those forecasts into interpretable resource-allocation signals: where aid should go and how the available capacity should be split across goods.
#
# ## area of interest
#
# We focus on Gedo, Bakool, and the Buur Hakaba district in Bay. Buur Hakaba is modeled as its own water-price area; food pressure for Buur Hakaba uses the available Bay WFP market proxy because the current WFP CSV has no Buur Hakaba food rows.
#
# ![most affected districts](README/img/district_map.png)
#
# ## Data And Sybilion
#
# ### Somali Markets
#
# Regional markets for water and food prices.
#
# National market proxies are used for the Cost of Minimum Basket and fuel prices to optian a noition of purchasing power and as fuel prices dont vary much per region.
#
# ![Somalia common commodities](README/img/somalia_common_commodities.png)
#
# ### Weather Data
#
# Weather data comes from the Copernicus Climate Data Store, using ERA5-Land monthly averaged reanalysis, we mapped polygons over the affected regions and retrieved following values:
#
# - rainfall
# - relative humidity
# - average temperature
#
# ![Gedo weather Sybilion forecasts](README/img/gedo_weather_sybilion_forecasts.png)
#
# ## Agent Layer
#
# Funding is the bottleneck. The agent receives the funding and allocates ressources where they are needed the most.
#
# The agents logic comprised of a formula which you can see with.

# %%
# !python app.py --mode cached --reasoning formula
# Out:
# [app] mode=cached, data_source=cache, forecast_source=cache
# [predictions] Gedo polygon: [(42.8903167, 4.3140417), (43.0996111, 3.0833333), (41.5229722, 1.2651944), (40.9924083, 2.7923778), (42.0586444, 4.1903472), (42.8903167, 4.3140417)]
# [predictions] CDS bbox [north, west, south, east]: [4.414041699999999, 40.8924083, 1.1651943999999999, 43.1996111]
# [predictions] Loaded cached weather data: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/gedo_monthly_weather_2006_2025.csv
# [predictions] Loaded cached weather forecast for rainfall_mm_per_day: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/rainfall_mm_per_day_forecast.json
# [predictions] Loaded cached weather forecast for relative_humidity_pct: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/relative_humidity_pct_forecast.json
# [predictions] Loaded cached weather forecast for temperature_avg_c: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/temperature_avg_c_forecast.json
# [app] Weather loaded: rows=240, path=/home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/gedo_monthly_weather_2006_2025.csv, range=2006-2025
# [predictions] Extended stale water series with seasonal monthly mean: 2022-11-01 to 2026-05-01.
# [predictions] Loaded Somalia water price proxy: 2011-01-01 to 2026-05-01, 185 rows, aggregation=mean, missing 0->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/somalia_water_sybilion_forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/somalia_water_sybilion_forecast.png
# [predictions] Loaded Somalia CMB USD series: 2011-01-01 to 2026-04-01, 184 rows, missing 0->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_cmb/forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_cmb/somalia_cmb_sybilion_forecast.png
# [predictions] Extended fuel series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded global fuel price proxy from WFP Somalia fuel rows: 2014-10-01 to 2026-05-01, 140 rows, aggregation=median, missing 6->0.
# [predictions] Building local seasonal forecast: global_fuel_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_fuel/global_fuel_sybilion_forecast.png
#
# === Kennwerte ===
# weather.rainfall_mm_per_day_mean: 0.9664
# weather.temperature_avg_c_mean: 28.4638
# weather.relative_humidity_pct_mean: 50.6060
# weather.rainfall_mm_per_day: last=2025-12-01 value=0.1019; next=2026-01-01 forecast=0.2414; horizon_mean=0.5502
# weather.relative_humidity_pct: last=2025-12-01 value=44.0723; next=2026-01-01 forecast=47.7132; horizon_mean=50.6386
# weather.temperature_avg_c: last=2025-12-01 value=29.9770; next=2026-01-01 forecast=28.6905; horizon_mean=28.5799
# water.national_price: last=2026-05-01 value=22485.1385; next=2026-06-01 forecast=23760.5593; horizon_mean=23564.6160
# food.cmb_national_usd: last=2026-04-01 value=172.5030; next=2026-05-01 forecast=171.5037; horizon_mean=171.2621
# fuel.global_proxy: last=2026-05-01 value=38.0875; next=2026-06-01 forecast=41.4786; horizon_mean=42.1061
# [app] Building agent decision from regional predictions: regions=Buur Hakaba, Bakool, Gedo, source=local
# [predictions] Extended stale buur_hakaba water series with seasonal monthly mean: 2017-03-01 to 2026-05-01.
# [predictions] Loaded buur_hakaba regional water price proxy: 2011-01-01 to 2026-05-01, 185 rows, districts=1, missing 4->0.
# [predictions] Building local seasonal forecast: buur_hakaba_water_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/buur_hakaba/buur_hakaba_water_sybilion_forecast.png
# [predictions] Using Bay WFP food-price proxy for Buur Hakaba.
# [predictions] Extended Bay food series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded Bay regional food price proxy: 1995-07-01 to 2026-05-01, 371 rows, aggregation=median, missing 24->0.
# [predictions] Building local seasonal forecast: buur_hakaba_food_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/buur_hakaba/buur_hakaba_food_sybilion_forecast.png
# [predictions] Extended stale bakool water series with seasonal monthly mean: 2022-11-01 to 2026-05-01.
# [predictions] Loaded bakool regional water price proxy: 2011-01-01 to 2026-05-01, 185 rows, districts=5, missing 0->0.
# [predictions] Building local seasonal forecast: bakool_water_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/bakool/bakool_water_sybilion_forecast.png
# [predictions] Extended Bakool food series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded Bakool regional food price proxy: 1999-11-01 to 2026-05-01, 319 rows, aggregation=median, missing 36->0.
# [predictions] Building local seasonal forecast: bakool_food_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/bakool/bakool_food_sybilion_forecast.png
# [predictions] Extended stale gedo water series with seasonal monthly mean: 2022-11-01 to 2026-05-01.
# [predictions] Loaded gedo regional water price proxy: 2011-01-01 to 2026-05-01, 185 rows, districts=6, missing 0->0.
# [predictions] Building local seasonal forecast: gedo_water_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/gedo/gedo_water_sybilion_forecast.png
# [predictions] Extended Gedo food series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded Gedo regional food price proxy: 2017-04-01 to 2026-05-01, 110 rows, aggregation=median, missing 9->0.
# [predictions] Building local seasonal forecast: gedo_food_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/gedo/gedo_food_sybilion_forecast.png
#
# === Agent Decisions ===
#
# region: Buur Hakaba
# regional_budget: 11,10%
# budget_allocation:
#   water_supplies: 0,91%
#   water_infrastructure: 6,61%
#   food_supplies: 1,67%
#   fuel: 1,91%
# scores:
#   water_supplies: 0.8255
#   water_infrastructure: 0.6346
#   food_supplies: 0.8695
#   fuel: 0.6470
#
# region: Bakool
# regional_budget: 31,80%
# budget_allocation:
#   water_supplies: 2,54%
#   water_infrastructure: 19,90%
#   food_supplies: 4,14%
#   fuel: 5,22%
# scores:
#   water_supplies: 0.8610
#   water_infrastructure: 0.6581
#   food_supplies: 0.7964
#   fuel: 0.6466
#
# region: Gedo
# regional_budget: 57,10%
# budget_allocation:
#   water_supplies: 3,60%
#   water_infrastructure: 36,75%
#   food_supplies: 6,12%
#   fuel: 10,63%
# scores:
#   water_supplies: 0.7369
#   water_infrastructure: 0.5296
#   food_supplies: 0.6472
#   fuel: 0.6251
#
# === Formulas ===
# drought_score: sigmoid(DROUGHT_TEMPERATURE_WEIGHT * temperature_slope - DROUGHT_RAINFALL_WEIGHT * rainfall_slope - DROUGHT_HUMIDITY_WEIGHT * humidity_slope)
# water_supplies: WEIGHT_WATER_SUPPLIES * sigmoid(SLOPE_WEIGHT * water_slope + LEVEL_WEIGHT * water_level + DROUGHT_WEIGHT * drought_score + UNCERTAINTY_WEIGHT * water_uncertainty)
# water_infrastructure: WEIGHT_WATER_INFRASTRUCTURE * sigmoid(LEVEL_WEIGHT * water_level + DROUGHT_WEIGHT * drought_score + UNCERTAINTY_WEIGHT * water_uncertainty)
# food_supplies: WEIGHT_FOOD_SUPPLIES * sigmoid(SLOPE_WEIGHT * food_slope + LEVEL_WEIGHT * food_level + FOOD_DROUGHT_WEIGHT * drought_score + UNCERTAINTY_WEIGHT * food_uncertainty)
# fuel: WEIGHT_FUEL * sigmoid(SLOPE_WEIGHT * fuel_slope + LEVEL_WEIGHT * fuel_level + FUEL_CROSS_SECTOR_WEIGHT * mean(water_pressure, structural_water_pressure, food_pressure) + UNCERTAINTY_WEIGHT * fuel_uncertainty)
# budget_allocation: softmax(cargo_score * effective_unit_cost / SOFTMAX_TEMPERATURE) * regional_budget
# effective_unit_cost: base_unit_cost / accessibility
# [app] Pipeline finished.

# %% [markdown]
# Weights and other constants are freely customizable.
#
# All agent constants live in `config.json`. Print the editable agent constants with short descriptions:

# %%
# !python app.py config-show
# Out:
# Agent-Konstanten (aenderbar)
# Config-Datei: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/config.json
#
# - agent.cargo_types                           ["water_supplies", "water_infrastructure", "food_supplies", "fuel"]
#   Hilfsgueter, auf die der Agent Budget verteilen kann.
# - agent.drought_weight                        2.0
#   Einfluss von Duerredruck auf Wasser und Nahrung.
# - agent.drought_temperature_weight            1.0
#   Einfluss steigender Temperatur auf den Duerrescore.
# - agent.drought_rainfall_weight               2.5
#   Einfluss von Regen auf den Duerrescore.
# - agent.drought_humidity_weight               0.8
#   Einfluss von Luftfeuchtigkeit auf den Duerrescore.
# - agent.missing_weather_drought_score         0.5
#   Fallback-Duerrescore, wenn keine Wetterprognose vorhanden ist.
# - agent.food_drought_weight                   1.2
#   Einfluss von Duerredruck auf Nahrungsscores.
# - agent.fuel_cross_sector_weight              0.9
#   Einfluss von Wasser- und Nahrungsscores auf Treibstoff.
# - agent.good_unit_costs.food_supplies         2.0
#   Basis-Lieferkosten fuer Nahrungsmittel.
# - agent.good_unit_costs.fuel                  3.0
#   Basis-Lieferkosten fuer Treibstoff.
# - agent.good_unit_costs.water_infrastructure  6.0
#   Basis-Lieferkosten fuer Wasserinfrastruktur.
# - agent.good_unit_costs.water_supplies        1.0
#   Basis-Lieferkosten fuer Wassergueter.
# - agent.level_weight                          0.8
#   Einfluss hoher Forecast-Level auf Scores.
# - agent.region_accessibility.Bakool           1.0
#   Erreichbarkeitsfaktor fuer Bakool-Lieferkosten.
# - agent.region_accessibility.Buur Hakaba      1.0
#   Erreichbarkeitsfaktor fuer Buur-Hakaba-Lieferkosten.
# - agent.region_accessibility.Gedo             0.7
#   Erreichbarkeitsfaktor fuer Gedo-Lieferkosten.
# - agent.region_populations.Bakool             564958
#   Bevoelkerung fuer Bakool-Budgetgewichtung.
# - agent.region_populations.Buur Hakaba        197198
#   Bevoelkerung fuer Buur-Hakaba-Budgetgewichtung.
# - agent.region_populations.Gedo               1014335
#   Bevoelkerung fuer Gedo-Budgetgewichtung.
# - agent.slope_weight                          2.5
#   Einfluss von Forecast-Trends auf Scores.
# - agent.softmax_temperature                   1.5
#   Steuert, wie stark Budget zu hohen Scores kippt.
# - agent.total_budget                          100.0
#   Gesamtbudget, das auf Regionen verteilt wird.
# - agent.uncertainty_weight                    0.3
#   Einfluss von Forecast-Unsicherheit auf Scores.
# - agent.weights.food_supplies                 1.15
#   Multiplikator fuer Nahrungsmitteldruck.
# - agent.weights.fuel                          0.9
#   Multiplikator fuer Treibstoffdruck.
# - agent.weights.water_infrastructure          0.85
#   Multiplikator fuer strukturellen Wasserdruck.
# - agent.weights.water_supplies                1.2
#   Multiplikator fuer kurzfristigen Wasserdruck.

# %% [markdown]
# Print one constant or section with a dotted key:

# %%
# !python app.py config-show agent.total_budget
# Out:
# agent.total_budget  100.0

# %%
# !python app.py config-show agent.weights
# Out:
# agent.weights.food_supplies         1.15
# agent.weights.fuel                  0.9
# agent.weights.water_infrastructure  0.85
# agent.weights.water_supplies        1.2

# %% [markdown]
# Update one agent constant with `config-set`; values are parsed as JSON, so numbers, booleans, lists, and objects keep their type. Only `agent.*` keys can be changed from the CLI:

# %%
# README command: python app.py config-set agent.total_budget 100
print("Skipped README command: python app.py config-set agent.total_budget 100")
print("Reason: config mutation is disabled by default.")
print("To run it manually, execute the README command in a terminal after confirming credentials/side effects.")
# Out:
# Skipped README command: python app.py config-set agent.total_budget 100
# Reason: config mutation is disabled by default.
# To run it manually, execute the README command in a terminal after confirming credentials/side effects.

# %%
# README command: python app.py config-set agent.weights.water_supplies 1.35
print("Skipped README command: python app.py config-set agent.weights.water_supplies 1.35")
print("Reason: config mutation is disabled by default.")
print("To run it manually, execute the README command in a terminal after confirming credentials/side effects.")
# Out:
# Skipped README command: python app.py config-set agent.weights.water_supplies 1.35
# Reason: config mutation is disabled by default.
# To run it manually, execute the README command in a terminal after confirming credentials/side effects.

# %% [markdown]
# ## Usage
#
# Install dependencies:

# %%
# README command: python -m pip install -r requirements.txt
print("Skipped README command: python -m pip install -r requirements.txt")
print("Reason: dependency installation is disabled by default.")
print("To run it manually, execute the README command in a terminal after confirming credentials/side effects.")
# Out:
# Skipped README command: python -m pip install -r requirements.txt
# Reason: dependency installation is disabled by default.
# To run it manually, execute the README command in a terminal after confirming credentials/side effects.

# %% [markdown]
# Live runs require a Sybilion token via `SYBILION_API_TOKEN` or `API_KEY.txt`. Fresh Copernicus weather fetches require CDS credentials via `CDSAPI_KEY` / `CDSAPI_URL` or a `.cdsapirc` file.
#
# Run the full live pipeline, including fresh weather data, new Sybilion forecasts, and agent allocation. This fetches Gedo weather data from Copernicus and submits new Sybilion jobs for weather, water, CMB, fuel, regional water, and regional food forecasts.

# %%
# README command: python app.py
print("Skipped README command: python app.py")
print("Reason: live/API forecast jobs are disabled by default.")
print("To run it manually, execute the README command in a terminal after confirming credentials/side effects.")
# Out:
# Skipped README command: python app.py
# Reason: live/API forecast jobs are disabled by default.
# To run it manually, execute the README command in a terminal after confirming credentials/side effects.

# %%
# README command: python app.py run
print("Skipped README command: python app.py run")
print("Reason: live/API forecast jobs are disabled by default.")
print("To run it manually, execute the README command in a terminal after confirming credentials/side effects.")
# Out:
# Skipped README command: python app.py run
# Reason: live/API forecast jobs are disabled by default.
# To run it manually, execute the README command in a terminal after confirming credentials/side effects.

# %% [markdown]
# Run from cached data and cached/local forecasts:

# %%
# !python app.py --mode cached
# Out:
# [app] mode=cached, data_source=cache, forecast_source=cache
# [predictions] Gedo polygon: [(42.8903167, 4.3140417), (43.0996111, 3.0833333), (41.5229722, 1.2651944), (40.9924083, 2.7923778), (42.0586444, 4.1903472), (42.8903167, 4.3140417)]
# [predictions] CDS bbox [north, west, south, east]: [4.414041699999999, 40.8924083, 1.1651943999999999, 43.1996111]
# [predictions] Loaded cached weather data: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/gedo_monthly_weather_2006_2025.csv
# [predictions] Loaded cached weather forecast for rainfall_mm_per_day: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/rainfall_mm_per_day_forecast.json
# [predictions] Loaded cached weather forecast for relative_humidity_pct: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/relative_humidity_pct_forecast.json
# [predictions] Loaded cached weather forecast for temperature_avg_c: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/temperature_avg_c_forecast.json
# [app] Weather loaded: rows=240, path=/home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/gedo_monthly_weather_2006_2025.csv, range=2006-2025
# [predictions] Extended stale water series with seasonal monthly mean: 2022-11-01 to 2026-05-01.
# [predictions] Loaded Somalia water price proxy: 2011-01-01 to 2026-05-01, 185 rows, aggregation=mean, missing 0->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/somalia_water_sybilion_forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/somalia_water_sybilion_forecast.png
# [predictions] Loaded Somalia CMB USD series: 2011-01-01 to 2026-04-01, 184 rows, missing 0->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_cmb/forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_cmb/somalia_cmb_sybilion_forecast.png
# [predictions] Extended fuel series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded global fuel price proxy from WFP Somalia fuel rows: 2014-10-01 to 2026-05-01, 140 rows, aggregation=median, missing 6->0.
# [predictions] Building local seasonal forecast: global_fuel_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_fuel/global_fuel_sybilion_forecast.png
#
# === Kennwerte ===
# weather.rainfall_mm_per_day_mean: 0.9664
# weather.temperature_avg_c_mean: 28.4638
# weather.relative_humidity_pct_mean: 50.6060
# weather.rainfall_mm_per_day: last=2025-12-01 value=0.1019; next=2026-01-01 forecast=0.2414; horizon_mean=0.5502
# weather.relative_humidity_pct: last=2025-12-01 value=44.0723; next=2026-01-01 forecast=47.7132; horizon_mean=50.6386
# weather.temperature_avg_c: last=2025-12-01 value=29.9770; next=2026-01-01 forecast=28.6905; horizon_mean=28.5799
# water.national_price: last=2026-05-01 value=22485.1385; next=2026-06-01 forecast=23760.5593; horizon_mean=23564.6160
# food.cmb_national_usd: last=2026-04-01 value=172.5030; next=2026-05-01 forecast=171.5037; horizon_mean=171.2621
# fuel.global_proxy: last=2026-05-01 value=38.0875; next=2026-06-01 forecast=41.4786; horizon_mean=42.1061
# [app] Building agent decision from regional predictions: regions=Buur Hakaba, Bakool, Gedo, source=local
# [predictions] Extended stale buur_hakaba water series with seasonal monthly mean: 2017-03-01 to 2026-05-01.
# [predictions] Loaded buur_hakaba regional water price proxy: 2011-01-01 to 2026-05-01, 185 rows, districts=1, missing 4->0.
# [predictions] Building local seasonal forecast: buur_hakaba_water_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/buur_hakaba/buur_hakaba_water_sybilion_forecast.png
# [predictions] Using Bay WFP food-price proxy for Buur Hakaba.
# [predictions] Extended Bay food series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded Bay regional food price proxy: 1995-07-01 to 2026-05-01, 371 rows, aggregation=median, missing 24->0.
# [predictions] Building local seasonal forecast: buur_hakaba_food_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/buur_hakaba/buur_hakaba_food_sybilion_forecast.png
# [predictions] Extended stale bakool water series with seasonal monthly mean: 2022-11-01 to 2026-05-01.
# [predictions] Loaded bakool regional water price proxy: 2011-01-01 to 2026-05-01, 185 rows, districts=5, missing 0->0.
# [predictions] Building local seasonal forecast: bakool_water_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/bakool/bakool_water_sybilion_forecast.png
# [predictions] Extended Bakool food series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded Bakool regional food price proxy: 1999-11-01 to 2026-05-01, 319 rows, aggregation=median, missing 36->0.
# [predictions] Building local seasonal forecast: bakool_food_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/bakool/bakool_food_sybilion_forecast.png
# [predictions] Extended stale gedo water series with seasonal monthly mean: 2022-11-01 to 2026-05-01.
# [predictions] Loaded gedo regional water price proxy: 2011-01-01 to 2026-05-01, 185 rows, districts=6, missing 0->0.
# [predictions] Building local seasonal forecast: gedo_water_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/gedo/gedo_water_sybilion_forecast.png
# [predictions] Extended Gedo food series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded Gedo regional food price proxy: 2017-04-01 to 2026-05-01, 110 rows, aggregation=median, missing 9->0.
# [predictions] Building local seasonal forecast: gedo_food_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/gedo/gedo_food_sybilion_forecast.png
#
# === Agent Decisions ===
#
# region: Buur Hakaba
# regional_budget: 11,10%
# budget_allocation:
#   water_supplies: 0,91%
#   water_infrastructure: 6,61%
#   food_supplies: 1,67%
#   fuel: 1,91%
# scores:
#   water_supplies: 0.8255
#   water_infrastructure: 0.6346
#   food_supplies: 0.8695
#   fuel: 0.6470
#
# region: Bakool
# regional_budget: 31,80%
# budget_allocation:
#   water_supplies: 2,54%
#   water_infrastructure: 19,90%
#   food_supplies: 4,14%
#   fuel: 5,22%
# scores:
#   water_supplies: 0.8610
#   water_infrastructure: 0.6581
#   food_supplies: 0.7964
#   fuel: 0.6466
#
# region: Gedo
# regional_budget: 57,10%
# budget_allocation:
#   water_supplies: 3,60%
#   water_infrastructure: 36,75%
#   food_supplies: 6,12%
#   fuel: 10,63%
# scores:
#   water_supplies: 0.7369
#   water_infrastructure: 0.5296
#   food_supplies: 0.6472
#   fuel: 0.6251
#
# === Overall Reasoning ===
# 1. Most resources go to water_infrastructure: 63,26% overall.
#    Strongest concrete driver: Gedo: drought pressure supports water infrastructure for these forecasts (value=0.2404, contribution=+0.4808).
# 2. The largest regional share goes to Gedo: 57,10%.
#    This is driven by the population-weighted regional split: population=1014335.
# 3. Inside that region, the largest goods allocation is water_infrastructure: 36,75%.
#    Strongest concrete driver: drought pressure supports water infrastructure for these forecasts (value=0.2404, contribution=+0.4808).
# [app] Pipeline finished.

# %%
# !python app.py run --mode cached
# Out:
# [app] mode=cached, data_source=cache, forecast_source=cache
# [predictions] Gedo polygon: [(42.8903167, 4.3140417), (43.0996111, 3.0833333), (41.5229722, 1.2651944), (40.9924083, 2.7923778), (42.0586444, 4.1903472), (42.8903167, 4.3140417)]
# [predictions] CDS bbox [north, west, south, east]: [4.414041699999999, 40.8924083, 1.1651943999999999, 43.1996111]
# [predictions] Loaded cached weather data: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/gedo_monthly_weather_2006_2025.csv
# [predictions] Loaded cached weather forecast for rainfall_mm_per_day: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/rainfall_mm_per_day_forecast.json
# [predictions] Loaded cached weather forecast for relative_humidity_pct: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/relative_humidity_pct_forecast.json
# [predictions] Loaded cached weather forecast for temperature_avg_c: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/temperature_avg_c_forecast.json
# [app] Weather loaded: rows=240, path=/home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/gedo_monthly_weather_2006_2025.csv, range=2006-2025
# [predictions] Extended stale water series with seasonal monthly mean: 2022-11-01 to 2026-05-01.
# [predictions] Loaded Somalia water price proxy: 2011-01-01 to 2026-05-01, 185 rows, aggregation=mean, missing 0->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/somalia_water_sybilion_forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/somalia_water_sybilion_forecast.png
# [predictions] Loaded Somalia CMB USD series: 2011-01-01 to 2026-04-01, 184 rows, missing 0->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_cmb/forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_cmb/somalia_cmb_sybilion_forecast.png
# [predictions] Extended fuel series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded global fuel price proxy from WFP Somalia fuel rows: 2014-10-01 to 2026-05-01, 140 rows, aggregation=median, missing 6->0.
# [predictions] Building local seasonal forecast: global_fuel_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_fuel/global_fuel_sybilion_forecast.png
#
# === Kennwerte ===
# weather.rainfall_mm_per_day_mean: 0.9664
# weather.temperature_avg_c_mean: 28.4638
# weather.relative_humidity_pct_mean: 50.6060
# weather.rainfall_mm_per_day: last=2025-12-01 value=0.1019; next=2026-01-01 forecast=0.2414; horizon_mean=0.5502
# weather.relative_humidity_pct: last=2025-12-01 value=44.0723; next=2026-01-01 forecast=47.7132; horizon_mean=50.6386
# weather.temperature_avg_c: last=2025-12-01 value=29.9770; next=2026-01-01 forecast=28.6905; horizon_mean=28.5799
# water.national_price: last=2026-05-01 value=22485.1385; next=2026-06-01 forecast=23760.5593; horizon_mean=23564.6160
# food.cmb_national_usd: last=2026-04-01 value=172.5030; next=2026-05-01 forecast=171.5037; horizon_mean=171.2621
# fuel.global_proxy: last=2026-05-01 value=38.0875; next=2026-06-01 forecast=41.4786; horizon_mean=42.1061
# [app] Building agent decision from regional predictions: regions=Buur Hakaba, Bakool, Gedo, source=local
# [predictions] Extended stale buur_hakaba water series with seasonal monthly mean: 2017-03-01 to 2026-05-01.
# [predictions] Loaded buur_hakaba regional water price proxy: 2011-01-01 to 2026-05-01, 185 rows, districts=1, missing 4->0.
# [predictions] Building local seasonal forecast: buur_hakaba_water_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/buur_hakaba/buur_hakaba_water_sybilion_forecast.png
# [predictions] Using Bay WFP food-price proxy for Buur Hakaba.
# [predictions] Extended Bay food series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded Bay regional food price proxy: 1995-07-01 to 2026-05-01, 371 rows, aggregation=median, missing 24->0.
# [predictions] Building local seasonal forecast: buur_hakaba_food_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/buur_hakaba/buur_hakaba_food_sybilion_forecast.png
# [predictions] Extended stale bakool water series with seasonal monthly mean: 2022-11-01 to 2026-05-01.
# [predictions] Loaded bakool regional water price proxy: 2011-01-01 to 2026-05-01, 185 rows, districts=5, missing 0->0.
# [predictions] Building local seasonal forecast: bakool_water_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/bakool/bakool_water_sybilion_forecast.png
# [predictions] Extended Bakool food series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded Bakool regional food price proxy: 1999-11-01 to 2026-05-01, 319 rows, aggregation=median, missing 36->0.
# [predictions] Building local seasonal forecast: bakool_food_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/bakool/bakool_food_sybilion_forecast.png
# [predictions] Extended stale gedo water series with seasonal monthly mean: 2022-11-01 to 2026-05-01.
# [predictions] Loaded gedo regional water price proxy: 2011-01-01 to 2026-05-01, 185 rows, districts=6, missing 0->0.
# [predictions] Building local seasonal forecast: gedo_water_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/gedo/gedo_water_sybilion_forecast.png
# [predictions] Extended Gedo food series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded Gedo regional food price proxy: 2017-04-01 to 2026-05-01, 110 rows, aggregation=median, missing 9->0.
# [predictions] Building local seasonal forecast: gedo_food_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/gedo/gedo_food_sybilion_forecast.png
#
# === Agent Decisions ===
#
# region: Buur Hakaba
# regional_budget: 11,10%
# budget_allocation:
#   water_supplies: 0,91%
#   water_infrastructure: 6,61%
#   food_supplies: 1,67%
#   fuel: 1,91%
# scores:
#   water_supplies: 0.8255
#   water_infrastructure: 0.6346
#   food_supplies: 0.8695
#   fuel: 0.6470
#
# region: Bakool
# regional_budget: 31,80%
# budget_allocation:
#   water_supplies: 2,54%
#   water_infrastructure: 19,90%
#   food_supplies: 4,14%
#   fuel: 5,22%
# scores:
#   water_supplies: 0.8610
#   water_infrastructure: 0.6581
#   food_supplies: 0.7964
#   fuel: 0.6466
#
# region: Gedo
# regional_budget: 57,10%
# budget_allocation:
#   water_supplies: 3,60%
#   water_infrastructure: 36,75%
#   food_supplies: 6,12%
#   fuel: 10,63%
# scores:
#   water_supplies: 0.7369
#   water_infrastructure: 0.5296
#   food_supplies: 0.6472
#   fuel: 0.6251
#
# === Overall Reasoning ===
# 1. Most resources go to water_infrastructure: 63,26% overall.
#    Strongest concrete driver: Gedo: drought pressure supports water infrastructure for these forecasts (value=0.2404, contribution=+0.4808).
# 2. The largest regional share goes to Gedo: 57,10%.
#    This is driven by the population-weighted regional split: population=1014335.
# 3. Inside that region, the largest goods allocation is water_infrastructure: 36,75%.
#    Strongest concrete driver: drought pressure supports water infrastructure for these forecasts (value=0.2404, contribution=+0.4808).
# [app] Pipeline finished.

# %% [markdown]
# Generate a browser dashboard that visualizes agent output and prediction curves:

# %%
# !python app.py dashboard
# Out:
# [app] Building dashboard data: mode=cached, forecast_source=cache
# [predictions] Gedo polygon: [(42.8903167, 4.3140417), (43.0996111, 3.0833333), (41.5229722, 1.2651944), (40.9924083, 2.7923778), (42.0586444, 4.1903472), (42.8903167, 4.3140417)]
# [predictions] CDS bbox [north, west, south, east]: [4.414041699999999, 40.8924083, 1.1651943999999999, 43.1996111]
# [predictions] Loaded cached weather data: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/gedo_monthly_weather_2006_2025.csv
# [predictions] Loaded cached weather forecast for rainfall_mm_per_day: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/rainfall_mm_per_day_forecast.json
# [predictions] Loaded cached weather forecast for relative_humidity_pct: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/relative_humidity_pct_forecast.json
# [predictions] Loaded cached weather forecast for temperature_avg_c: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/temperature_avg_c_forecast.json
# [predictions] Extended stale water series with seasonal monthly mean: 2022-11-01 to 2026-05-01.
# [predictions] Loaded Somalia water price proxy: 2011-01-01 to 2026-05-01, 185 rows, aggregation=mean, missing 0->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/somalia_water_sybilion_forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/somalia_water_sybilion_forecast.png
# [predictions] Loaded Somalia CMB USD series: 2011-01-01 to 2026-04-01, 184 rows, missing 0->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_cmb/forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_cmb/somalia_cmb_sybilion_forecast.png
# [predictions] Extended fuel series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded global fuel price proxy from WFP Somalia fuel rows: 2014-10-01 to 2026-05-01, 140 rows, aggregation=median, missing 6->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_fuel/global_fuel_sybilion_forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_fuel/global_fuel_sybilion_forecast.png
# [predictions] Extended stale buur_hakaba water series with seasonal monthly mean: 2017-03-01 to 2026-05-01.
# [predictions] Loaded buur_hakaba regional water price proxy: 2011-01-01 to 2026-05-01, 185 rows, districts=1, missing 4->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/buur_hakaba/buur_hakaba_water_sybilion_forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/buur_hakaba/buur_hakaba_water_sybilion_forecast.png
# [predictions] Using Bay WFP food-price proxy for Buur Hakaba.
# [predictions] Extended Bay food series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded Bay regional food price proxy: 1995-07-01 to 2026-05-01, 371 rows, aggregation=median, missing 24->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/buur_hakaba/buur_hakaba_food_sybilion_forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/buur_hakaba/buur_hakaba_food_sybilion_forecast.png
# [predictions] Extended stale bakool water series with seasonal monthly mean: 2022-11-01 to 2026-05-01.
# [predictions] Loaded bakool regional water price proxy: 2011-01-01 to 2026-05-01, 185 rows, districts=5, missing 0->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/bakool/bakool_water_sybilion_forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/bakool/bakool_water_sybilion_forecast.png
# [predictions] Extended Bakool food series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded Bakool regional food price proxy: 1999-11-01 to 2026-05-01, 319 rows, aggregation=median, missing 36->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/bakool/bakool_food_sybilion_forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/bakool/bakool_food_sybilion_forecast.png
# [predictions] Extended stale gedo water series with seasonal monthly mean: 2022-11-01 to 2026-05-01.
# [predictions] Loaded gedo regional water price proxy: 2011-01-01 to 2026-05-01, 185 rows, districts=6, missing 0->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/gedo/gedo_water_sybilion_forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/gedo/gedo_water_sybilion_forecast.png
# [predictions] Extended Gedo food series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded Gedo regional food price proxy: 2017-04-01 to 2026-05-01, 110 rows, aggregation=median, missing 9->0.
# [predictions] Loaded cached forecast: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/gedo/gedo_food_sybilion_forecast.json
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/gedo/gedo_food_sybilion_forecast.png
# Dashboard written to: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/reports/aid_dashboard.html

# %% [markdown]
# The command writes `reports/aid_dashboard.html`, which can be opened directly in a browser. It uses cached/local data by default so it does not start live forecast jobs unless you pass `--mode live`.
#
# Print a slick minimalist forecast UI in the terminal:

# %%
# !python app.py prediction-ui
# Out:
# +------------------------------------------------------------------------------+
# | NATIONAL WATER PRICE                                                         |
# | SOS water proxy  |  data/somalia/water/sybilion/somalia_water_sybilion_fore. |
# +------------------------------------------------------------------------------+
# | next 2026-06-01  23.76k                                           avg 23.56k |
# | last 2026-11-01  22.98k                                         trend -3.28% |
# | horizon 6 months                                                  band 1.31k |
# +------------------------------------------------------------------------------+
# | date        forecast      interval        shape                              |
# | 2026-06-01      23.76k    23.20k-24.34k  ######################..            |
# | 2026-07-01      23.70k    23.17k-24.25k  ####################....            |
# | 2026-08-01      23.59k    22.99k-24.21k  #################.......            |
# | 2026-09-01      23.85k    23.29k-24.42k  ########################            |
# | 2026-10-01      23.50k    22.86k-24.16k  ##############..........            |
# | 2026-11-01      22.98k    22.01k-23.99k  #.......................            |
# +------------------------------------------------------------------------------+

# %%
# !python app.py prediction-ui --prediction regional-food --region Gedo
# Out:
# +------------------------------------------------------------------------------+
# | GEDO FOOD PRICE                                                              |
# | Regional food proxy  |  data/somalia/sybilion_regional_food/gedo/gedo_food_. |
# +------------------------------------------------------------------------------+
# | next 2026-06-01  43.07                                             avg 42.52 |
# | last 2026-11-01  44.56                                          trend +3.46% |
# | horizon 6 months                                                   band 8.50 |
# +------------------------------------------------------------------------------+
# | date        forecast      interval        shape                              |
# | 2026-06-01       43.07      38.76-47.37  ###############.........            |
# | 2026-07-01       40.35      36.31-44.38  #.......................            |
# | 2026-08-01       40.92      36.83-45.02  ###.....................            |
# | 2026-09-01       42.83      38.55-47.12  ##############..........            |
# | 2026-10-01       43.39      39.05-47.72  #################.......            |
# | 2026-11-01       44.56      40.10-49.01  ########################            |
# +------------------------------------------------------------------------------+

# %%
# !python app.py prediction-ui --prediction weather --weather-metric rainfall_mm_per_day
# Out:
# +------------------------------------------------------------------------------+
# | GEDO RAINFALL MM PER DAY                                                     |
# | Weather forecast  |  data/weather/sybilion_gedo/rainfall_mm_per_day_forecas. |
# +------------------------------------------------------------------------------+
# | next 2026-01-01  0.24                                               avg 0.56 |
# | last 2026-06-01  0.80                                          trend +55.54% |
# | horizon 6 months                                                   band 1.04 |
# +------------------------------------------------------------------------------+
# | date        forecast      interval        shape                              |
# | 2026-01-01        0.24        0.03-0.49  #.......................            |
# | 2026-02-01        1.07        0.51-1.82  ########################            |
# | 2026-03-01        0.38        0.05-0.80  ####....................            |
# | 2026-04-01        0.55        0.00-1.93  #########...............            |
# | 2026-05-01        0.31        0.00-1.28  ##......................            |
# | 2026-06-01        0.80        0.56-1.07  ################........            |
# +------------------------------------------------------------------------------+

# %% [markdown]
# Run the compound drought-shock scenario for the live demo. It keeps cached data unchanged, modifies rainfall, humidity, and temperature forecasts in memory, and compares baseline allocation/reasoning with the stressed decision:

# %%
# !python scenarios/rainfall_weather_shock/run_rainfall_shock.py
# Out:
# [predictions] Gedo polygon: [(42.8903167, 4.3140417), (43.0996111, 3.0833333), (41.5229722, 1.2651944), (40.9924083, 2.7923778), (42.0586444, 4.1903472), (42.8903167, 4.3140417)]
# [predictions] CDS bbox [north, west, south, east]: [4.414041699999999, 40.8924083, 1.1651943999999999, 43.1996111]
# [predictions] Loaded cached weather data: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/gedo_monthly_weather_2006_2025.csv
# [predictions] Loaded cached weather forecast for rainfall_mm_per_day: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/rainfall_mm_per_day_forecast.json
# [predictions] Loaded cached weather forecast for relative_humidity_pct: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/relative_humidity_pct_forecast.json
# [predictions] Loaded cached weather forecast for temperature_avg_c: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/weather/sybilion_gedo/temperature_avg_c_forecast.json
# [predictions] Extended stale buur_hakaba water series with seasonal monthly mean: 2017-03-01 to 2026-05-01.
# [predictions] Loaded buur_hakaba regional water price proxy: 2011-01-01 to 2026-05-01, 185 rows, districts=1, missing 4->0.
# [predictions] Building local seasonal forecast: buur_hakaba_water_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/water/sybilion/regional/buur_hakaba/buur_hakaba_water_sybilion_forecast.png
# [predictions] Using Bay WFP food-price proxy for Buur Hakaba.
# [predictions] Extended Bay food series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded Bay regional food price proxy: 1995-07-01 to 2026-05-01, 371 rows, aggregation=median, missing 24->0.
# [predictions] Building local seasonal forecast: buur_hakaba_food_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_regional_food/buur_hakaba/buur_hakaba_food_sybilion_forecast.png
# [predictions] Extended fuel series with seasonal monthly median: 2026-05-01 to 2026-05-01.
# [predictions] Loaded global fuel price proxy from WFP Somalia fuel rows: 2014-10-01 to 2026-05-01, 140 rows, aggregation=median, missing 6->0.
# [predictions] Building local seasonal forecast: global_fuel_sybilion
# [predictions] Saved prediction plot: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/data/somalia/sybilion_fuel/global_fuel_sybilion_forecast.png
#
# === baseline ===
# region: Buur Hakaba
# drought_score: 0.2404
# allocation:
#   water_supplies: 9.42% (score=0.6809)
#   water_infrastructure: 52.12% (score=0.5412)
#   food_supplies: 17.34% (score=0.7984)
#   fuel: 21.12% (score=0.6307)
# top reasons:
#   water_supplies: drought pressure supports water supplies for these forecasts (value=0.2404, contribution=+0.4808).
#   water_infrastructure: drought pressure supports water infrastructure for these forecasts (value=0.2404, contribution=+0.4808).
#   food_supplies: food price level supports food supplies for these forecasts (value=0.4816, contribution=+0.3853).
#   fuel: water and food pressure spillover supports fuel for these forecasts (value=0.6328, contribution=+0.5695).
#
# === rainfall_shock ===
# region: Buur Hakaba
# drought_score: 0.7790
# allocation:
#   water_supplies: 7.16% (score=0.9527)
#   water_infrastructure: 65.43% (score=0.7117)
#   food_supplies: 13.19% (score=0.9344)
#   fuel: 14.22% (score=0.6606)
# top reasons:
#   water_supplies: drought pressure supports water supplies for these forecasts (value=0.7790, contribution=+1.5580).
#   water_infrastructure: drought pressure supports water infrastructure for these forecasts (value=0.7790, contribution=+1.5580).
#   food_supplies: drought pressure supports food supplies for these forecasts (value=0.7790, contribution=+0.9348).
#   fuel: water and food pressure spillover supports fuel for these forecasts (value=0.8146, contribution=+0.7331).
#
# === Scenario Change Summary ===
# allocation changed for: water_supplies, water_infrastructure, food_supplies, fuel
# top reasoning changed for: water_supplies, water_infrastructure, food_supplies, fuel
# wrote: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/scenarios/rainfall_weather_shock/output

# %% [markdown]
# For a narrated notebook walkthrough, open `scenarios/rainfall_weather_shock/rainfall_weather_shock.ipynb`.
#
# Run the agent for selected regions or a custom budget:

# %%
# README command: python app.py run --agent-region Gedo
print("Skipped README command: python app.py run --agent-region Gedo")
print("Reason: live/API forecast jobs are disabled by default.")
print("To run it manually, execute the README command in a terminal after confirming credentials/side effects.")
# Out:
# Skipped README command: python app.py run --agent-region Gedo
# Reason: live/API forecast jobs are disabled by default.
# To run it manually, execute the README command in a terminal after confirming credentials/side effects.

# %%
# README command: python app.py run --agent-region "Buur Hakaba"
print("Skipped README command: python app.py run --agent-region \"Buur Hakaba\"")
print("Reason: live/API forecast jobs are disabled by default.")
print("To run it manually, execute the README command in a terminal after confirming credentials/side effects.")
# Out:
# Skipped README command: python app.py run --agent-region "Buur Hakaba"
# Reason: live/API forecast jobs are disabled by default.
# To run it manually, execute the README command in a terminal after confirming credentials/side effects.

# %%
# README command: python app.py run --agent-regions "Buur Hakaba" Bakool Gedo --agent-budget 12000000
print("Skipped README command: python app.py run --agent-regions \"Buur Hakaba\" Bakool Gedo --agent-budget 12000000")
print("Reason: live/API forecast jobs are disabled by default.")
print("To run it manually, execute the README command in a terminal after confirming credentials/side effects.")
# Out:
# Skipped README command: python app.py run --agent-regions "Buur Hakaba" Bakool Gedo --agent-budget 12000000
# Reason: live/API forecast jobs are disabled by default.
# To run it manually, execute the README command in a terminal after confirming credentials/side effects.

# %% [markdown]
# Use local seasonal baselines for regional agent water/food inputs instead of live Sybilion forecasts:

# %%
# README command: python app.py run --agent-forecast-source local
print("Skipped README command: python app.py run --agent-forecast-source local")
print("Reason: live/API forecast jobs are disabled by default.")
print("To run it manually, execute the README command in a terminal after confirming credentials/side effects.")
# Out:
# Skipped README command: python app.py run --agent-forecast-source local
# Reason: live/API forecast jobs are disabled by default.
# To run it manually, execute the README command in a terminal after confirming credentials/side effects.

# %% [markdown]
# Inspect and update agent configuration:

# %%
# !python app.py config-show
# Out:
# Agent-Konstanten (aenderbar)
# Config-Datei: /home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/aid-ressource-allocation-engine/config.json
#
# - agent.cargo_types                           ["water_supplies", "water_infrastructure", "food_supplies", "fuel"]
#   Hilfsgueter, auf die der Agent Budget verteilen kann.
# - agent.drought_weight                        2.0
#   Einfluss von Duerredruck auf Wasser und Nahrung.
# - agent.drought_temperature_weight            1.0
#   Einfluss steigender Temperatur auf den Duerrescore.
# - agent.drought_rainfall_weight               2.5
#   Einfluss von Regen auf den Duerrescore.
# - agent.drought_humidity_weight               0.8
#   Einfluss von Luftfeuchtigkeit auf den Duerrescore.
# - agent.missing_weather_drought_score         0.5
#   Fallback-Duerrescore, wenn keine Wetterprognose vorhanden ist.
# - agent.food_drought_weight                   1.2
#   Einfluss von Duerredruck auf Nahrungsscores.
# - agent.fuel_cross_sector_weight              0.9
#   Einfluss von Wasser- und Nahrungsscores auf Treibstoff.
# - agent.good_unit_costs.food_supplies         2.0
#   Basis-Lieferkosten fuer Nahrungsmittel.
# - agent.good_unit_costs.fuel                  3.0
#   Basis-Lieferkosten fuer Treibstoff.
# - agent.good_unit_costs.water_infrastructure  6.0
#   Basis-Lieferkosten fuer Wasserinfrastruktur.
# - agent.good_unit_costs.water_supplies        1.0
#   Basis-Lieferkosten fuer Wassergueter.
# - agent.level_weight                          0.8
#   Einfluss hoher Forecast-Level auf Scores.
# - agent.region_accessibility.Bakool           1.0
#   Erreichbarkeitsfaktor fuer Bakool-Lieferkosten.
# - agent.region_accessibility.Buur Hakaba      1.0
#   Erreichbarkeitsfaktor fuer Buur-Hakaba-Lieferkosten.
# - agent.region_accessibility.Gedo             0.7
#   Erreichbarkeitsfaktor fuer Gedo-Lieferkosten.
# - agent.region_populations.Bakool             564958
#   Bevoelkerung fuer Bakool-Budgetgewichtung.
# - agent.region_populations.Buur Hakaba        197198
#   Bevoelkerung fuer Buur-Hakaba-Budgetgewichtung.
# - agent.region_populations.Gedo               1014335
#   Bevoelkerung fuer Gedo-Budgetgewichtung.
# - agent.slope_weight                          2.5
#   Einfluss von Forecast-Trends auf Scores.
# - agent.softmax_temperature                   1.5
#   Steuert, wie stark Budget zu hohen Scores kippt.
# - agent.total_budget                          100.0
#   Gesamtbudget, das auf Regionen verteilt wird.
# - agent.uncertainty_weight                    0.3
#   Einfluss von Forecast-Unsicherheit auf Scores.
# - agent.weights.food_supplies                 1.15
#   Multiplikator fuer Nahrungsmitteldruck.
# - agent.weights.fuel                          0.9
#   Multiplikator fuer Treibstoffdruck.
# - agent.weights.water_infrastructure          0.85
#   Multiplikator fuer strukturellen Wasserdruck.
# - agent.weights.water_supplies                1.2
#   Multiplikator fuer kurzfristigen Wasserdruck.

# %%
# !python app.py config-show agent.total_budget
# Out:
# agent.total_budget  100.0

# %%
# README command: python app.py config-set agent.total_budget 100
print("Skipped README command: python app.py config-set agent.total_budget 100")
print("Reason: config mutation is disabled by default.")
print("To run it manually, execute the README command in a terminal after confirming credentials/side effects.")
# Out:
# Skipped README command: python app.py config-set agent.total_budget 100
# Reason: config mutation is disabled by default.
# To run it manually, execute the README command in a terminal after confirming credentials/side effects.

# %%
# README command: python app.py config-set agent.weights.water_supplies 1.35
print("Skipped README command: python app.py config-set agent.weights.water_supplies 1.35")
print("Reason: config mutation is disabled by default.")
print("To run it manually, execute the README command in a terminal after confirming credentials/side effects.")
# Out:
# Skipped README command: python app.py config-set agent.weights.water_supplies 1.35
# Reason: config mutation is disabled by default.
# To run it manually, execute the README command in a terminal after confirming credentials/side effects.

# %% [markdown]
# See [USAGE.md](USAGE.md) for the full CLI documentation.
#
# ## data
#
# ### input csvs
#
# | scope | signal | csv path | description |
# | --- | --- | --- | --- |
# | national / district panel | water prices | `data/somalia/water/som_water_price_2011_2022.csv` | Somalia water-price observations by `Region`, `District`, `month`, and `water_price`. The pipeline aggregates this to a national monthly water-shortage proxy using mean or median. |
# | national | Cost of Minimum Basket (CMB) | `data/somalia/fsnau_cmb_total_basket_cmb_sorghum.csv` | FSNAU Total Basket CMB with red sorghum as the main cereal. The pipeline extracts monthly USD columns and averages across regions to estimate what a Somali household pays for the minimum food basket. |
# | national / regional market panel | fuel and food prices | `data/somalia/wfp_food_prices_som.csv` | WFP Somalia market-price data. The pipeline filters fuel commodities for the national fuel proxy and food rows by `admin1` for regional food-price proxies. |
#
# ### weather API
#
# Weather features for rainfall, average temperature, and relative humidity are pulled from the **Copernicus Climate Data Store API**, using **ERA5-Land monthly averaged reanalysis** clipped to polygons.
#
# ### prediction series csvs
#
# | scope | signal | csv path | description |
# | --- | --- | --- | --- |
# | national | water-price monthly proxy | `data/somalia/water/sybilion/somalia_water_price_monthly.csv` | Clean monthly `date`, `value`, `source` series produced from the raw water-price panel. Missing months are interpolated; stale data can be seasonally extended. |
# | regional, Buur Hakaba | water-price monthly proxy | `data/somalia/water/sybilion/regional/buur_hakaba/buur_hakaba_water_price_monthly.csv` | Clean monthly Buur Hakaba water-price proxy from `District=Buur Hakaba` rows listed in `domain/regions.py`. |
# | regional, Bakool | water-price monthly proxy | `data/somalia/water/sybilion/regional/bakool/bakool_water_price_monthly.csv` | Clean monthly Bakool water-price proxy, computed as the simple average across the Bakool districts listed in `domain/regions.py`. |
# | regional, Gedo | water-price monthly proxy | `data/somalia/water/sybilion/regional/gedo/gedo_water_price_monthly.csv` | Clean monthly Gedo water-price proxy, computed as the simple average across the Gedo districts listed in `domain/regions.py`. |
# | national | CMB monthly USD proxy | `data/somalia/sybilion_cmb/somalia_cmb_usd_monthly.csv` | Clean monthly `date`, `value`, `source` series extracted from the FSNAU CMB table and averaged across regions. |
# | national | fuel monthly proxy | `data/somalia/sybilion_fuel/global_fuel_price_monthly.csv` | Clean monthly `date`, `value`, `source` series from WFP fuel rows, aggregated with the configured mean or median. |
# | regional, Buur Hakaba food proxy | food-price monthly proxy | `data/somalia/sybilion_regional_food/buur_hakaba/buur_hakaba_food_price_monthly.csv` | Clean monthly food-price proxy for Buur Hakaba, sourced from WFP `admin1=Bay` food rows because `data/somalia/wfp_food_prices_som.csv` has no Buur Hakaba food rows. |
# | regional, Bakool | food-price monthly proxy | `data/somalia/sybilion_regional_food/bakool/bakool_food_price_monthly.csv` | Clean monthly Bakool food-price proxy from WFP `admin1=Bakool` food rows, aggregated with the configured mean or median. |
# | regional, Gedo | food-price monthly proxy | `data/somalia/sybilion_regional_food/gedo/gedo_food_price_monthly.csv` | Clean monthly Gedo food-price proxy from WFP `admin1=Gedo` food rows, aggregated with the configured mean or median. |
# | national | water demand / shortage proxy | `data/somalia/water/sybilion/somalia_water_sybilion_forecast.csv` | Sybilion forecast for the national water-price proxy, including point forecasts and quantiles. |
# | regional, Buur Hakaba | water demand / shortage proxy | `data/somalia/water/sybilion/regional/buur_hakaba/buur_hakaba_water_sybilion_forecast.csv` | Regional forecast for the Buur Hakaba water-price proxy, including point forecasts and quantiles. |
# | regional, Bakool | water demand / shortage proxy | `data/somalia/water/sybilion/regional/bakool/bakool_water_sybilion_forecast.csv` | Regional forecast for the Bakool water-price proxy, including point forecasts and quantiles. |
# | regional, Gedo | water demand / shortage proxy | `data/somalia/water/sybilion/regional/gedo/gedo_water_sybilion_forecast.csv` | Regional forecast for the Gedo water-price proxy, including point forecasts and quantiles. |
# | national | food basket cost | `data/somalia/sybilion_cmb/somalia_cmb_sybilion_forecast.csv` | Sybilion forecast for national CMB in USD, including point forecasts and quantiles. |
# | national | fuel cost proxy | `data/somalia/sybilion_fuel/global_fuel_sybilion_forecast.csv` | Sybilion forecast for the aggregated fuel-price proxy, including point forecasts and quantiles. |
# | regional, Buur Hakaba food proxy | food-price proxy | `data/somalia/sybilion_regional_food/buur_hakaba/buur_hakaba_food_sybilion_forecast.csv` | Forecast for the Bay WFP food-price proxy used by the Buur Hakaba agent decision. |
# | regional, Bakool | food-price proxy | `data/somalia/sybilion_regional_food/bakool/bakool_food_sybilion_forecast.csv` | Forecast for the Bakool regional WFP food-price proxy, including point forecasts and quantiles. |
# | regional, Gedo | food-price proxy | `data/somalia/sybilion_regional_food/gedo/gedo_food_sybilion_forecast.csv` | Forecast for the Gedo regional WFP food-price proxy, including point forecasts and quantiles. |
