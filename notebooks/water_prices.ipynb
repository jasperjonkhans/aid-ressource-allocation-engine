# %%
import pandas as pd 

df = pd.read_csv("/home/jjonkhans/HACKATHONS/ZERO_ONE_HACK/project/data/somalia/water/som_water_price_2011_2022.csv")

df.head()
df.District.unique()
# Out:
# array(['Borama', 'Baki', 'Lughaye', 'Zeylac', 'Hargeysa', 'Berbera',
#        'Gebiley', 'Burco', 'Buuhoodle', 'Owdweyne', 'Sheikh',
#        'Laas Caanood', 'Caynabo', 'Taleex', 'Xudun', 'Ceerigaabo',
#        'Ceel Afweyn', 'Laasqoray', 'Bossaso', 'Bandarbeyla', 'Caluula',
#        'Iskushuban', 'Qandala', 'Qardho', 'Garoowe', 'Burtinle', 'Eyl',
#        'Gaalkacyo', 'Galdogob', 'Hobyo', 'Jariiban', 'Xarardheere',
#        'Dhuusamarreeb', 'Cabudwaaq', 'Cadaado', 'Ceel Buur', 'Ceel Dheer',
#        'Belet Weyne', 'Bulo Burto', 'Jalalaqsi', 'Jowhar', 'Adan Yabaal',
#        'Balcad', 'Cadale', 'Mogadishu', 'Marka', 'Afgooye', 'Baraawe',
#        'Kurtunwaarey', 'Qoryooley', 'Sablaale', 'Wanla Weyn', 'Baydhaba',
#        'Buur Hakaba', 'Diinsoor', 'Qansax Dheere', 'Xudur', 'Ceel Barde',
#        'Tayeeglow', 'Waajid', 'Rab Dhuure', 'Garbahaarey', 'Baardheere',
#        'Belet Xaawo', 'Ceel Waaq', 'Doolow', 'Luuq', "Bu'aale", 'Jilib',
# ...

# %%
bay_districts = [
    "Baydhaba",
    "Buur Hakaba",
    "Diinsoor",
    "Qansax Dheere"
]

bakool_districts = [
    "Xudur",
    "Ceel Barde",
    "Tayeeglow",
    "Waajid",
    "Rab Dhuure"
]

gedo_districts = [
    "Garbahaarey",
    "Baardheere",
    "Belet Xaawo",
    "Ceel Waaq",
    "Doolow",
    "Luuq"
]
